# %%
import numpy

# %%
# This a proof of the notebook
funct= lambda x,y: numpy.sin(x)*numpy.cos(y[:, numpy.newaxis])
x= numpy.linspace(-numpy.pi, numpy.pi, 100)
y= numpy.linspace(0, 2*numpy.pi, 100)
z= funct(x,y)
z.shape
# Out:
# (100, 100)

# %%
print (x[0])
# Out:
# -3.14159265359

# %%
# to not produce pop up plots
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
fig= plt.figure()
ax= fig.add_subplot(111, projection='3d')
#ax.plot(x,y,z)
ax.plot_surface(x,y,z, rstride=4, cstride=4, linewidth=1, alpha=0.25)

# %%
fig= plt.figure()
ax1=fig.add_subplot(111)
ax1.plot(x,y)

# %%
x= 1.0
y= numpy.array([1.0, 2.0])
z= randn(10,10)
plot(mean(z, axis=1)) # axis= 1 rows axis=0, columns

# %%
import pandas as pd
pd.read_csv?
